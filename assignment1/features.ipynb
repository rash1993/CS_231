# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=29000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %%
# Extract Features
For each image we will compute a Histogram of Oriented
Gradients (HOG) as well as a color histogram using the hue channel in HSV
color space. We form our final feature vector for each image by concatenating
the HOG and color histogram feature vectors.

Roughly speaking, HOG should capture the texture of the image while ignoring
color information, and the color histogram represents the color of the input
image while ignoring texture. As a result, we expect that using both together
ought to work better than using either alone. Verifying this assumption would
be a good thing to try for the bonus section.

The `hog_feature` and `color_histogram_hsv` functions both operate on a single
image and return a feature vector for that image. The extract_features
function takes a set of images and a list of feature functions and evaluates
each feature function on each image, storing the results in a matrix where
each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 29000 images
# Done extracting features for 2000 / 29000 images
# Done extracting features for 3000 / 29000 images
# Done extracting features for 4000 / 29000 images
# Done extracting features for 5000 / 29000 images
# Done extracting features for 6000 / 29000 images
# Done extracting features for 7000 / 29000 images
# Done extracting features for 8000 / 29000 images
# Done extracting features for 9000 / 29000 images
# Done extracting features for 10000 / 29000 images
# Done extracting features for 11000 / 29000 images
# Done extracting features for 12000 / 29000 images
# Done extracting features for 13000 / 29000 images
# Done extracting features for 14000 / 29000 images
# Done extracting features for 15000 / 29000 images
# Done extracting features for 16000 / 29000 images
# Done extracting features for 17000 / 29000 images
# Done extracting features for 18000 / 29000 images
# Done extracting features for 19000 / 29000 images
# Done extracting features for 20000 / 29000 images
# Done extracting features for 21000 / 29000 images
# Done extracting features for 22000 / 29000 images
# Done extracting features for 23000 / 29000 images
# Done extracting features for 24000 / 29000 images
# Done extracting features for 25000 / 29000 images
# Done extracting features for 26000 / 29000 images
# Done extracting features for 27000 / 29000 images
# Done extracting features for 28000 / 29000 images

# %%
print X_train_feats.shape
# Out:
# (19000, 155)

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM
svm = LinearSVM()

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
            loss_hist = svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs, num_iters=1500, verbose=True)
            y_train_pred = svm.predict(X_train_feats)
            
            train_accuracy = np.mean(y_train == y_train_pred)
            
            y_val_pred = svm.predict(X_val_feats)            
            validation_accuracy = np.mean(y_val == y_val_pred)
            
            results[(lr, rs)] = (train_accuracy, validation_accuracy)
            if best_val<validation_accuracy:
                best_val = validation_accuracy
                best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# (19000, 155)
# iteration 0 / 1500: loss 83.342033
# iteration 100 / 1500: loss 81.863340
# iteration 200 / 1500: loss 80.437066
# iteration 300 / 1500: loss 79.017058
# iteration 400 / 1500: loss 77.621707
# iteration 500 / 1500: loss 76.278817
# iteration 600 / 1500: loss 74.914502
# iteration 700 / 1500: loss 73.637977
# iteration 800 / 1500: loss 72.355984
# iteration 900 / 1500: loss 71.098441
# iteration 1000 / 1500: loss 69.858745
# iteration 1100 / 1500: loss 68.665146
# iteration 1200 / 1500: loss 67.472731
# iteration 1300 / 1500: loss 66.325119
# iteration 1400 / 1500: loss 65.176895
# (19000, 155)
# iteration 0 / 1500: loss 559.715452
# iteration 100 / 1500: loss 459.839622
# iteration 200 / 1500: loss 378.070988
# iteration 300 / 1500: loss 311.149971
# iteration 400 / 1500: loss 256.342629
# iteration 500 / 1500: loss 211.489069
# iteration 600 / 1500: loss 174.772945
# iteration 700 / 1500: loss 144.700846
# iteration 800 / 1500: loss 120.094202
# iteration 900 / 1500: loss 99.943551
# iteration 1000 / 1500: loss 83.458588
# iteration 1100 / 1500: loss 69.957367
# iteration 1200 / 1500: loss 58.900534
# iteration 1300 / 1500: loss 49.850591
# iteration 1400 / 1500: loss 42.443749
# (19000, 155)
# iteration 0 / 1500: loss 282.771205
# iteration 100 / 1500: loss 45.680223
# iteration 200 / 1500: loss 13.914659
# iteration 300 / 1500: loss 9.658309
# iteration 400 / 1500: loss 9.088255
# iteration 500 / 1500: loss 9.011820
# iteration 600 / 1500: loss 9.001582
# iteration 700 / 1500: loss 9.000207
# iteration 800 / 1500: loss 9.000024
# iteration 900 / 1500: loss 9.000000
# iteration 1000 / 1500: loss 8.999997
# iteration 1100 / 1500: loss 8.999997
# iteration 1200 / 1500: loss 8.999996
# iteration 1300 / 1500: loss 8.999996
# iteration 1400 / 1500: loss 8.999997
# (19000, 155)
# iteration 0 / 1500: loss 8.999993
# iteration 100 / 1500: loss 8.999934
# iteration 200 / 1500: loss 8.999887
# iteration 300 / 1500: loss 8.999833
# iteration 400 / 1500: loss 8.999794
# iteration 500 / 1500: loss 8.999767
# iteration 600 / 1500: loss 8.999767
# iteration 700 / 1500: loss 8.999746
# iteration 800 / 1500: loss 8.999732
# iteration 900 / 1500: loss 8.999669
# iteration 1000 / 1500: loss 8.999705
# iteration 1100 / 1500: loss 8.999711
# iteration 1200 / 1500: loss 8.999712
# iteration 1300 / 1500: loss 8.999721
# iteration 1400 / 1500: loss 8.999687
# (19000, 155)
# iteration 0 / 1500: loss 9.001588
# iteration 100 / 1500: loss 9.000168
# iteration 200 / 1500: loss 8.999982
# iteration 300 / 1500: loss 8.999978
# iteration 400 / 1500: loss 8.999974
# iteration 500 / 1500: loss 8.999960
# iteration 600 / 1500: loss 8.999970
# iteration 700 / 1500: loss 8.999967
# iteration 800 / 1500: loss 8.999962
# iteration 900 / 1500: loss 8.999967
# iteration 1000 / 1500: loss 8.999965
# iteration 1100 / 1500: loss 8.999965
# iteration 1200 / 1500: loss 8.999954
# iteration 1300 / 1500: loss 8.999964
# iteration 1400 / 1500: loss 8.999968
# (19000, 155)
# iteration 0 / 1500: loss 9.000283
# iteration 100 / 1500: loss 8.999997
# iteration 200 / 1500: loss 8.999996
# iteration 300 / 1500: loss 8.999997
# iteration 400 / 1500: loss 8.999996
# iteration 500 / 1500: loss 8.999996
# iteration 600 / 1500: loss 8.999997
# iteration 700 / 1500: loss 8.999997
# iteration 800 / 1500: loss 8.999996
# iteration 900 / 1500: loss 8.999997
# iteration 1000 / 1500: loss 8.999996
# iteration 1100 / 1500: loss 8.999997
# iteration 1200 / 1500: loss 8.999996
# iteration 1300 / 1500: loss 8.999997
# iteration 1400 / 1500: loss 8.999996
# (19000, 155)
# iteration 0 / 1500: loss 8.999992
# iteration 100 / 1500: loss 8.999651
# iteration 200 / 1500: loss 8.999705
# iteration 300 / 1500: loss 8.999638
# iteration 400 / 1500: loss 8.999664
# iteration 500 / 1500: loss 8.999621
# iteration 600 / 1500: loss 8.999589
# iteration 700 / 1500: loss 8.999676
# iteration 800 / 1500: loss 8.999700
# iteration 900 / 1500: loss 8.999601
# iteration 1000 / 1500: loss 8.999646
# iteration 1100 / 1500: loss 8.999631
# iteration 1200 / 1500: loss 8.999589
# iteration 1300 / 1500: loss 8.999544
# iteration 1400 / 1500: loss 8.999648
# (19000, 155)
# iteration 0 / 1500: loss 9.002831
# iteration 100 / 1500: loss 8.999960
# iteration 200 / 1500: loss 8.999961
# iteration 300 / 1500: loss 8.999971
# iteration 400 / 1500: loss 8.999969
# iteration 500 / 1500: loss 8.999965
# iteration 600 / 1500: loss 8.999967
# iteration 700 / 1500: loss 8.999970
# iteration 800 / 1500: loss 8.999973
# iteration 900 / 1500: loss 8.999958
# iteration 1000 / 1500: loss 8.999970
# iteration 1100 / 1500: loss 8.999968
# iteration 1200 / 1500: loss 8.999975
# iteration 1300 / 1500: loss 8.999968
# iteration 1400 / 1500: loss 8.999966
# (19000, 155)
# iteration 0 / 1500: loss 9.000318
# iteration 100 / 1500: loss 9.000001
# iteration 200 / 1500: loss 9.000000
# iteration 300 / 1500: loss 9.000000
# iteration 400 / 1500: loss 9.000000
# iteration 500 / 1500: loss 9.000000
# iteration 600 / 1500: loss 9.000000
# iteration 700 / 1500: loss 9.000001
# iteration 800 / 1500: loss 8.999999
# iteration 900 / 1500: loss 9.000000
# iteration 1000 / 1500: loss 9.000000
# iteration 1100 / 1500: loss 9.000001
# iteration 1200 / 1500: loss 9.000000
# iteration 1300 / 1500: loss 9.000000
# iteration 1400 / 1500: loss 8.999999
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.099158 val accuracy: 0.097000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.099526 val accuracy: 0.098000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.414474 val accuracy: 0.416000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.415158 val accuracy: 0.410000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.414579 val accuracy: 0.415000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.410000 val accuracy: 0.405000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.416737 val accuracy: 0.406000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.408158 val accuracy: 0.400000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.315316 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.416000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.312

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (29000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

best_net = None
net = TwoLayerNet(input_dim, hidden_dim, num_classes, std=1e-1)
stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            learning_rate=1e-1, reg=1e-5,
            num_iters=2500, verbose=True)
print 'Final training loss: ', stats['loss_history'][-1]

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################

##########Tunning the heperparamters############
learning_rates = [1e-1, 1e-2, 1e0]
regularization_strengths = [1e-5, 1e-6, 1e-4]

results = {}
best_val = -1
best_nn = None

for lr in learning_rates:
    for rs in regularization_strengths:
            from cs231n.classifiers.neural_net import TwoLayerNet
            net = TwoLayerNet(input_dim, hidden_dim, num_classes, std=1e-1)
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val, lr, rs, num_iters=1500, verbose=True)   
            
            y_train_pred = net.predict(X_train_feats)
            
            train_accuracy = np.mean(y_train == y_train_pred)
            
            y_val_pred = net.predict(X_val_feats)            
            validation_accuracy = np.mean(y_val == y_val_pred)
            
            results[(lr, rs)] = (train_accuracy, validation_accuracy)
            if best_val<validation_accuracy:
                best_val = validation_accuracy
                best_nn = net
                best_stat = stats



# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val



print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 2500: loss 3.442939
# iteration 100 / 2500: loss 1.445911
# iteration 200 / 2500: loss 1.493783
# iteration 300 / 2500: loss 1.246909
# iteration 400 / 2500: loss 1.179234
# iteration 500 / 2500: loss 0.998486
# iteration 600 / 2500: loss 1.069991
# iteration 700 / 2500: loss 1.218646
# iteration 800 / 2500: loss 1.182534
# iteration 900 / 2500: loss 1.137536
# iteration 1000 / 2500: loss 1.115584
# iteration 1100 / 2500: loss 0.984367
# iteration 1200 / 2500: loss 0.956085
# iteration 1300 / 2500: loss 1.045861
# iteration 1400 / 2500: loss 0.939628
# iteration 1500 / 2500: loss 1.142997
# iteration 1600 / 2500: loss 0.983492
# iteration 1700 / 2500: loss 1.090378
# iteration 1800 / 2500: loss 1.051392
# iteration 1900 / 2500: loss 0.901149
# iteration 2000 / 2500: loss 0.798470
# iteration 2100 / 2500: loss 0.842490
# iteration 2200 / 2500: loss 0.895291
# iteration 2300 / 2500: loss 0.755844
# iteration 2400 / 2500: loss 0.811315
# Final training loss:  0.852557051945
# iteration 0 / 1500: loss 3.862054
# iteration 100 / 1500: loss 3.124079
# iteration 200 / 1500: loss 3.241716
# iteration 300 / 1500: loss 2.935233
# iteration 400 / 1500: loss 3.280726
# iteration 500 / 1500: loss 3.291155
# iteration 600 / 1500: loss 3.015373
# iteration 700 / 1500: loss 3.302402
# iteration 800 / 1500: loss 3.144573
# iteration 900 / 1500: loss 3.332043
# iteration 1000 / 1500: loss 3.429670
# iteration 1100 / 1500: loss 3.127130
# iteration 1200 / 1500: loss 3.147499
# iteration 1300 / 1500: loss 3.248506
# iteration 1400 / 1500: loss 3.248529
# iteration 0 / 1500: loss 3.601153
# iteration 100 / 1500: loss 3.075490
# iteration 200 / 1500: loss 2.821085
# iteration 300 / 1500: loss 3.054913
# iteration 400 / 1500: loss 2.918252
# iteration 500 / 1500: loss 3.136319
# iteration 600 / 1500: loss 3.150763
# iteration 700 / 1500: loss 3.065774
# iteration 800 / 1500: loss 3.029161
# iteration 900 / 1500: loss 3.016980
# iteration 1000 / 1500: loss 3.008039
# iteration 1100 / 1500: loss 3.011265
# iteration 1200 / 1500: loss 3.137853
# iteration 1300 / 1500: loss 2.988388
# iteration 1400 / 1500: loss 3.062845
# iteration 0 / 1500: loss 3.499046
# iteration 100 / 1500: loss 3.309590
# iteration 200 / 1500: loss 3.431145
# iteration 300 / 1500: loss 3.089456
# iteration 400 / 1500: loss 3.167827
# iteration 500 / 1500: loss 3.059832
# iteration 600 / 1500: loss 3.139595
# iteration 700 / 1500: loss 3.342046
# iteration 800 / 1500: loss 3.101550
# iteration 900 / 1500: loss 3.332882
# iteration 1000 / 1500: loss 2.998621
# iteration 1100 / 1500: loss 3.178653
# iteration 1200 / 1500: loss 3.315717
# iteration 1300 / 1500: loss 3.084458
# iteration 1400 / 1500: loss 3.347926
# iteration 0 / 1500: loss 3.655066
# iteration 100 / 1500: loss 3.644886
# iteration 200 / 1500: loss 3.718859
# iteration 300 / 1500: loss 3.682578
# iteration 400 / 1500: loss 3.478602
# iteration 500 / 1500: loss 3.406428
# iteration 600 / 1500: loss 3.546566
# iteration 700 / 1500: loss 3.583357
# iteration 800 / 1500: loss 3.381607
# iteration 900 / 1500: loss 3.545451
# iteration 1000 / 1500: loss 3.712504
# iteration 1100 / 1500: loss 3.489150
# iteration 1200 / 1500: loss 3.585968
# iteration 1300 / 1500: loss 3.396811
# iteration 1400 / 1500: loss 3.420467
# iteration 0 / 1500: loss 3.659069
# iteration 100 / 1500: loss 3.539256
# iteration 200 / 1500: loss 3.505698
# iteration 300 / 1500: loss 3.676690
# iteration 400 / 1500: loss 3.577007
# iteration 500 / 1500: loss 3.559620
# iteration 600 / 1500: loss 3.883680
# iteration 700 / 1500: loss 3.764017
# iteration 800 / 1500: loss 3.718501
# iteration 900 / 1500: loss 3.481580
# iteration 1000 / 1500: loss 3.495254
# iteration 1100 / 1500: loss 3.678514
# iteration 1200 / 1500: loss 3.474326
# iteration 1300 / 1500: loss 3.627407
# iteration 1400 / 1500: loss 3.786815
# iteration 0 / 1500: loss 3.566115
# iteration 100 / 1500: loss 3.285508
# iteration 200 / 1500: loss 3.490437
# iteration 300 / 1500: loss 3.195461
# iteration 400 / 1500: loss 3.439661
# iteration 500 / 1500: loss 3.252696
# iteration 600 / 1500: loss 3.145761
# iteration 700 / 1500: loss 3.457459
# iteration 800 / 1500: loss 3.304297
# iteration 900 / 1500: loss 3.184770
# iteration 1000 / 1500: loss 3.337938
# iteration 1100 / 1500: loss 3.115514
# iteration 1200 / 1500: loss 3.461941
# iteration 1300 / 1500: loss 3.596165
# iteration 1400 / 1500: loss 3.320478
# iteration 0 / 1500: loss 3.379913
# iteration 100 / 1500: loss 10.866108
# iteration 200 / 1500: loss 11.051951
# iteration 300 / 1500: loss 11.608015
# iteration 400 / 1500: loss 10.018947
# iteration 500 / 1500: loss 11.366480
# iteration 600 / 1500: loss 12.661913
# iteration 700 / 1500: loss 11.960678
# iteration 800 / 1500: loss 11.960425
# iteration 900 / 1500: loss 11.199199
# iteration 1000 / 1500: loss 12.276996
# iteration 1100 / 1500: loss 12.254308
# iteration 1200 / 1500: loss 10.704937
# iteration 1300 / 1500: loss 11.746932
# iteration 1400 / 1500: loss 11.511381
# iteration 0 / 1500: loss 3.872442
# iteration 100 / 1500: loss 11.588446
# iteration 200 / 1500: loss 11.319006
# iteration 300 / 1500: loss 10.335335
# iteration 400 / 1500: loss 11.060610
# iteration 500 / 1500: loss 11.760296
# iteration 600 / 1500: loss 11.412119
# iteration 700 / 1500: loss 11.373900
# iteration 800 / 1500: loss 12.427507
# iteration 900 / 1500: loss 11.339307
# iteration 1000 / 1500: loss 11.913991
# iteration 1100 / 1500: loss 11.532348
# iteration 1200 / 1500: loss 11.306520
# iteration 1300 / 1500: loss 12.064881
# iteration 1400 / 1500: loss 10.149752
# iteration 0 / 1500: loss 3.430014
# iteration 100 / 1500: loss 9.381942
# iteration 200 / 1500: loss 9.354745
# iteration 300 / 1500: loss 10.069833
# iteration 400 / 1500: loss 9.374119
# iteration 500 / 1500: loss 9.712995
# iteration 600 / 1500: loss 10.324130
# iteration 700 / 1500: loss 10.368486
# iteration 800 / 1500: loss 9.016527
# iteration 900 / 1500: loss 10.776852
# iteration 1000 / 1500: loss 11.034835
# iteration 1100 / 1500: loss 9.467233
# iteration 1200 / 1500: loss 10.259036
# iteration 1300 / 1500: loss 9.948393
# iteration 1400 / 1500: loss 10.396951
# lr 1.000000e-02 reg 1.000000e-06 train accuracy: 0.118621 val accuracy: 0.097000
# lr 1.000000e-02 reg 1.000000e-05 train accuracy: 0.103552 val accuracy: 0.108000
# lr 1.000000e-02 reg 1.000000e-04 train accuracy: 0.111552 val accuracy: 0.120000
# lr 1.000000e-01 reg 1.000000e-06 train accuracy: 0.124931 val accuracy: 0.131000
# lr 1.000000e-01 reg 1.000000e-05 train accuracy: 0.124793 val accuracy: 0.121000
# lr 1.000000e-01 reg 1.000000e-04 train accuracy: 0.112966 val accuracy: 0.119000
# lr 1.000000e+00 reg 1.000000e-06 train accuracy: 0.127069 val accuracy: 0.129000
# lr 1.000000e+00 reg 1.000000e-05 train accuracy: 0.140724 val accuracy: 0.149000
# lr 1.000000e+00 reg 1.000000e-04 train accuracy: 0.166276 val accuracy: 0.180000
# best validation accuracy achieved during cross-validation: 0.180000
# Final training loss:  11.6832303221

# %%
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')

plt.show()

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_nn.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.534

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
